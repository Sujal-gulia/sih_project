# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import  seaborn as sns

pd.pandas.set_option('display.max_columns',None)
pd.pandas.set_option('display.max_rows',None)

# %%
dataset = pd.read_csv('allergies.csv')
print(dataset.shape)
# Out:
# (794, 15)

# %%
features_with_na=[features for features in dataset.columns if dataset[features].isnull().sum()>1]

for features in features_with_na:
    print(features, np.round(dataset[features].isnull().mean(),4), '%missing values')
# Out:
# STOP 1.0 %missing values
# REACTION1 0.4836 %missing values
# DESCRIPTION1 0.4836 %missing values
# SEVERITY1 0.4836 %missing values
# REACTION2 0.6738 %missing values
# DESCRIPTION2 0.6738 %missing values
# SEVERITY2 0.6738 %missing values

# %%
for feature in features_with_na:
    data = dataset.copy()

    data[feature] = np.where(data[feature].isnull(), 1, 0)

    numeric_columns = dataset.select_dtypes(include=['number']).columns
    result = dataset.groupby('DESCRIPTION').agg({col: 'median' for col in numeric_columns})
    print(result)
    plt.title(result)
    plt.show()
# Out:
#                                  STOP          CODE    REACTION1    REACTION2
# DESCRIPTION
# Animal dander (substance)         NaN  2.642870e+08  878820003.0  271807003.0
# Aspirin                           NaN  1.191000e+03   21522001.0  247472004.0
# Bee venom (substance)             NaN  2.883280e+08  271807003.0          NaN
# Cow's milk (substance)            NaN  3.718001e+06  247472004.0  247472004.0
# Eggs (edible) (substance)         NaN  1.022630e+08  247472004.0  247472004.0
# Fish (substance)                  NaN  7.359710e+08  267036007.0  300359004.0
# Grass pollen (substance)          NaN  2.562770e+08          NaN          NaN
# House dust mite (organism)        NaN  2.601470e+08          NaN          NaN
# Ibuprofen                         NaN  5.640000e+03  878820003.0          NaN
# Latex (substance)                 NaN  1.110880e+08  247472004.0  247472004.0
# Lisinopril                        NaN  2.904600e+04   49727002.0  237849008.0
# ...

# %%
dataset = dataset.drop(['START','STOP','PATIENT','ENCOUNTER','CODE','SYSTEM','REACTION1','REACTION2'], axis=1)
print(dataset.head)
dataset.to_csv('modified_allergy.csv',index=False)
# Out:
# <bound method NDFrame.head of                          DESCRIPTION         TYPE     CATEGORY  \
# 0                  Latex (substance)      allergy  environment
# 1                    Mold (organism)      allergy  environment
# 2         House dust mite (organism)      allergy  environment
# 3          Animal dander (substance)      allergy  environment
# 4           Grass pollen (substance)      allergy  environment
# 5                            Aspirin      allergy   medication
# 6             Cow's milk (substance)      allergy         food
# 7              Soya bean (substance)      allergy         food
# 8              Shellfish (substance)      allergy         food
# 9             Cow's milk (substance)      allergy         food
# 10                   Mold (organism)      allergy  environment
# 11        House dust mite (organism)      allergy  environment
# 12         Animal dander (substance)      allergy  environment
# ...

# %%
categorical_features=[feature for feature in dataset.columns if data[feature].dtype=='O']
categorical_features
# Out:
# ['DESCRIPTION',
#  'TYPE',
#  'CATEGORY',
#  'DESCRIPTION1',
#  'SEVERITY1',
#  'DESCRIPTION2']
